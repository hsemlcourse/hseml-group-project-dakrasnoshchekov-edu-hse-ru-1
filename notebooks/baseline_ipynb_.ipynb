# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import warnings
warnings.simplefilter("ignore")
# %matplotlib inline

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score, precision_score, recall_score, f1_score
import random
random.seed(2026)
np.random.seed(2026)

# %%
df = pd.read_csv('rubik_solves_cleaned.csv')
df.columns
# Out:
# Index(['solve_id', 'solver', 'solve_time', 'pll', 'pll_time', 'Split', 'STM',
#        'STPS', 'ETM', 'ETPS', 'Solver_count', 'U', 'U2', 'L', 'L2', 'F', 'F2',
#        'R', 'R2', 'B', 'B2', 'D', 'D2', 'simul', 'ghost_move'],
#       dtype='object')

# %%
X = df.iloc[:, 6:]
y = df.pll_time
X
# Out:
#      STM   STPS  ETM   ETPS  Solver_count   U  U2  L  L2  F  F2   R  R2  B  \
# 0     18  13.14   18  13.14           125   8   1  0   0  0   0   5   2  0
# 1     16  15.53   16  15.53           125   5   1  0   0  0   0   8   0  0
# 2     17  11.11   17  11.11           125   8   0  0   0  0   0   5   2  0
# 3     19   9.74   19   9.74           125  10   0  0   0  0   0   5   2  0
# 4     15  17.86   15  17.86           125   6   0  0   0  2   0   6   1  0
# ..   ...    ...  ...    ...           ...  ..  .. ..  .. ..  ..  ..  .. ..
# 625   14  14.43   14  14.43           202   5   0  0   0  2   0   6   1  0
# 626   18   9.42   18   9.42           202   6   1  0   0  2   1   6   2  0
# 627   23  14.20   23  14.20            72   9   1  0   0  2   0  10   1  0
# 628   17  12.41   17  12.41            72   4   1  0   0  0   0   5   3  0
# 629   15  17.05   15  17.05            72   5   1  0   0  2   0   6   1  0
#
#      B2  D  D2  simul  ghost_move
# 0     0  2   0      2           1
# 1     0  2   0      0           0
# 2     0  2   0      2           1
# 3     0  2   0      3           0
# 4     0  0   0      0           0
# ..   .. ..  ..    ...         ...
# 625   0  0   0      0           0
# 626   0  0   0      0           0
# 627   0  0   0      0           0
# 628   0  4   0      1           1
# 629   0  0   0      0           0
#
# [630 rows x 19 columns]

# %%
from sklearn.model_selection import train_test_split



X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=10)

# %%
model1 = LinearRegression()
model1.fit(X_train, y_train)
y_pred = model1.predict(X_test)

print(model1.score(X_test, y_test))
print(r2_score(y_test, y_pred))
print(mean_squared_error(y_test, y_pred) ** 0.5)
# Out:
# 0.8734962633980593
# 0.8734962633980593
# 0.3466391271666204
